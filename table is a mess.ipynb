# %%
import pandas as pd
from pandas import Series,DataFrame

# %%
url = 'https://en.wikipedia.org/wiki/List_of_Presidents_of_the_United_States'

# %%
prez = pd.io.html.read_html(url)

# %%
prez[0]
# Out:
#                                                    0   \
# 0   None (1)       Federalist (1)       Democratic...
# 1                                                   №
# 2                                                   1
# 3                                            2 (1792)
# 4                                                   2
# 5                                                   3
# 6                                            5 (1804)
# 7                                                   4
# 8         Vacant April 20, 1812 – March 4, 1813 [n 5]
# 9                                            7 (1812)
# 10     Vacant November 23, 1814 – March 4, 1817 [n 5]
# 11                                                  5
# 12                                           9 (1820)
# 13                                                  6
# 14                                                  7
# 15     Vacant December 28, 1832 – March 4, 1833 [n 5]
# ...
